# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import tqdm

import pickle

from sklearn.neighbors import KNeighborsClassifier 
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import roc_curve, auc, PrecisionRecallDisplay
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from warnings import simplefilter
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC 

# from keras_visualizer import visualizer

# %%
# What version of Python do you have?
import sys

import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import platform

print(f"Python Platform: {platform.platform()}")
print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU') ) > 0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: macOS-13.0.1-arm64-arm-64bit
# Tensor Flow Version: 2.12.0
# Keras Version: 2.12.0
#
# Python 3.10.10 | packaged by conda-forge | (main, Mar 24 2023, 20:12:31) [Clang 14.0.6 ]
# Pandas 2.0.0
# Scikit-Learn 1.2.2
# GPU is available

# %% [markdown]
# ### Load the training set and testing set

# %%
imputed_train_data = pd.read_csv('/Users/yihongan/Desktop/lr_imputed_train.csv')
imputed_test_data = pd.read_csv('/Users/yihongan/Desktop/lr_imputed_test.csv')
imputed_train_data
# Out:
#                                                      url        age
# 0                            https://www.crossstitch.pk/  17.266665  \
# 1                 http://www.wikiwand.com/en/LATAM_Chile   9.200000
# 2                              http://www.iconmeals.com/   9.065753
# 3      http://calvaryepiscopalbatavia.org/wp-includes...   7.057534
# 4             www.sharpaviation.com.au/index.php/pt_home  27.353425
# ...                                                  ...        ...
# 14155                   http://lbcpzonasegurabeta.rf.gd/   9.638965
# 14156  https://www.e-serviceparts.info/landingpages/d...   4.575342
# 14157                           rzr.online.fr/resume.htm  14.227397
# 14158            en.wikipedia.org/wiki/Aldus_Corporation  22.191781
# 14159  http://www.askapache.com/online-tools/mac-lookup/  16.561644
#
#        num_suspicious_words  has_ip_address  is_url_shortened  length
# 0                         0               0                 0      27  \
# 1                         0               0                 0      38
# 2                         0               0                 0      25
# 3                         1               0                 0      68
# 4                         0               0                 0      42
# ...                     ...             ...               ...     ...
# 14155                     0               0                 0      32
# 14156                     0               0                 0     125
# 14157                     0               0                 0      24
# 14158                     0               0                 0      39
# 14159                     0               0                 0      49
#
#        subdomain_ratio  num_dots  num_www  num_dcom  ...  num_semic
# 0             0.666667         2        1         0  ...          0  \
# 1             0.421053         2        1         1  ...          0
# 2             0.680000         2        1         1  ...          0
# 3             0.397059         1        0         0  ...          0
# 4             0.571429         4        1         1  ...          0
# ...                ...       ...      ...       ...  ...        ...
# 14155         0.750000         2        0         0  ...          0
# 14156         0.184000         2        1         0  ...          0
# 14157         0.541667         3        0         0  ...          0
# 14158         0.410256         2        0         0  ...          0
# 14159         0.346939         2        1         1  ...          0
#
#        num_comma  login_time  num_ex_links  num_redirects  num_img
# 0              0    1.296597         247.0            1.0     95.0  \
# 1              0    0.093795          91.0            1.0      3.0
# 2              0    1.031102         105.0            1.0     20.0
# 3              0    0.640474           0.0            0.0      0.0
# 4              0    5.873612          76.0            1.0     11.0
# ...          ...         ...           ...            ...      ...
# 14155          0    0.734203           0.0            0.0      0.0
# 14156          0    0.046956           0.0            0.0      0.0
# 14157          0    1.753927           1.0            0.0      0.0
# 14158          0    0.298482         330.0            1.0     11.0
# 14159          0    1.858973         161.0            1.0      2.0
#
#        num_iframe  num_hidden  ext_tot_ratio  status
# 0             1.0         1.0          247.0       0
# 1             0.0         1.0           91.0       0
# 2             0.0         1.0          105.0       0
# 3             0.0         0.0            0.0       1
# 4             1.0         1.0           76.0       0
# ...           ...         ...            ...     ...
# 14155         0.0         0.0            0.0       1
# 14156         0.0         0.0            0.0       1
# 14157         0.0         0.0            1.0       0
# 14158         0.0         4.0          330.0       0
# 14159         0.0         0.0          161.0       0
#
# [14160 rows x 36 columns]

# %% [markdown]
# ### Preprogress both textual and numerical features

# %%
# Define input shapes
text_input_shape = (100,)
num_input_shape = (imputed_train_data.shape[1] - 2,)

# Numerical data
num_train = imputed_train_data.iloc[:, 1:(num_input_shape[0] + 1)].values
num_test = imputed_test_data.iloc[:, 1:(num_input_shape[0] + 1)].values

mean_sd_sc = StandardScaler()
num_train_std = mean_sd_sc.fit_transform(num_train)
num_test_std = mean_sd_sc.transform(num_test)

# Response
y_train = imputed_train_data.iloc[:, (num_input_shape[0] + 1)].values
y_test = imputed_test_data.iloc[:, (num_input_shape[0] + 1)].values.squeeze()

# %%
def confusion_matrix_heatmap(model, y_true, y_pred):
    plt.figure(figsize=(8,8))
    sns.heatmap(confusion_matrix(y_true, y_pred, normalize='true'),
                fmt='.1%',
                annot=True,
                cmap="Blues",
                xticklabels=['Predicted legitimate', 'Predicted phishing'],
                yticklabels=['Actual legitimate', 'Actual phishing'],
                annot_kws={"size": 14})
    plt.title(f'Normalized Confusion Matrix-{model}', {'fontsize':18})

# %% [markdown]
# ###  KNN Classification Model

# %%
knn_pipe = make_pipeline(StandardScaler(), KNeighborsClassifier(metric='euclidean'))

knn_parameters = [{
    'kneighborsclassifier__n_neighbors': np.arange(1, 20, 2)
}]
knn_grid_search = GridSearchCV(knn_pipe, knn_parameters, scoring='accuracy', cv=5, verbose=3, refit=True)
knn_grid_search.fit(num_train, y_train)

print("Best Accuracy: {}" .format(knn_grid_search.best_score_))
print("Best num of neighbors: {}" .format(knn_grid_search.best_estimator_))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END kneighborsclassifier__n_neighbors=1;, score=0.917 total time=   0.1s
# [CV 2/5] END kneighborsclassifier__n_neighbors=1;, score=0.915 total time=   0.1s
# [CV 3/5] END kneighborsclassifier__n_neighbors=1;, score=0.911 total time=   0.1s
# [CV 4/5] END kneighborsclassifier__n_neighbors=1;, score=0.914 total time=   0.1s
# [CV 5/5] END kneighborsclassifier__n_neighbors=1;, score=0.920 total time=   0.1s
# [CV 1/5] END kneighborsclassifier__n_neighbors=3;, score=0.920 total time=   0.1s
# [CV 2/5] END kneighborsclassifier__n_neighbors=3;, score=0.923 total time=   0.1s
# [CV 3/5] END kneighborsclassifier__n_neighbors=3;, score=0.921 total time=   0.1s
# [CV 4/5] END kneighborsclassifier__n_neighbors=3;, score=0.922 total time=   0.1s
# [CV 5/5] END kneighborsclassifier__n_neighbors=3;, score=0.929 total time=   0.1s
# [CV 1/5] END kneighborsclassifier__n_neighbors=5;, score=0.920 total time=   0.1s
# [CV 2/5] END kneighborsclassifier__n_neighbors=5;, score=0.917 total time=   0.1s
# [CV 3/5] END kneighborsclassifier__n_neighbors=5;, score=0.916 total time=   0.1s
# [CV 4/5] END kneighborsclassifier__n_neighbors=5;, score=0.919 total time=   0.1s
# [CV 5/5] END kneighborsclassifier__n_neighbors=5;, score=0.930 total time=   0.1s
# [CV 1/5] END kneighborsclassifier__n_neighbors=7;, score=0.919 total time=   0.1s
# [CV 2/5] END kneighborsclassifier__n_neighbors=7;, score=0.917 total time=   0.1s
# [CV 3/5] END kneighborsclassifier__n_neighbors=7;, score=0.909 total time=   0.1s
# [CV 4/5] END kneighborsclassifier__n_neighbors=7;, score=0.913 total time=   0.1s
# [CV 5/5] END kneighborsclassifier__n_neighbors=7;, score=0.926 total time=   0.1s
# [CV 1/5] END kneighborsclassifier__n_neighbors=9;, score=0.916 total time=   0.1s
# [CV 2/5] END kneighborsclassifier__n_neighbors=9;, score=0.920 total time=   0.1s
# [CV 3/5] END kneighborsclassifier__n_neighbors=9;, score=0.907 total time=   0.1s
# [CV 4/5] END kneighborsclassifier__n_neighbors=9;, score=0.910 total time=   0.1s
# [CV 5/5] END kneighborsclassifier__n_neighbors=9;, score=0.925 total time=   0.1s
# [CV 1/5] END kneighborsclassifier__n_neighbors=11;, score=0.912 total time=   0.1s
# [CV 2/5] END kneighborsclassifier__n_neighbors=11;, score=0.922 total time=   0.1s
# [CV 3/5] END kneighborsclassifier__n_neighbors=11;, score=0.904 total time=   0.1s
# [CV 4/5] END kneighborsclassifier__n_neighbors=11;, score=0.911 total time=   0.1s
# [CV 5/5] END kneighborsclassifier__n_neighbors=11;, score=0.919 total time=   0.1s
# [CV 1/5] END kneighborsclassifier__n_neighbors=13;, score=0.909 total time=   0.1s
# [CV 2/5] END kneighborsclassifier__n_neighbors=13;, score=0.921 total time=   0.1s
# [CV 3/5] END kneighborsclassifier__n_neighbors=13;, score=0.902 total time=   0.1s
# [CV 4/5] END kneighborsclassifier__n_neighbors=13;, score=0.907 total time=   0.1s
# [CV 5/5] END kneighborsclassifier__n_neighbors=13;, score=0.917 total time=   0.1s
# [CV 1/5] END kneighborsclassifier__n_neighbors=15;, score=0.907 total time=   0.1s
# [CV 2/5] END kneighborsclassifier__n_neighbors=15;, score=0.919 total time=   0.1s
# [CV 3/5] END kneighborsclassifier__n_neighbors=15;, score=0.899 total time=   0.1s
# [CV 4/5] END kneighborsclassifier__n_neighbors=15;, score=0.907 total time=   0.1s
# [CV 5/5] END kneighborsclassifier__n_neighbors=15;, score=0.915 total time=   0.1s
# [CV 1/5] END kneighborsclassifier__n_neighbors=17;, score=0.906 total time=   0.1s
# [CV 2/5] END kneighborsclassifier__n_neighbors=17;, score=0.917 total time=   0.1s
# [CV 3/5] END kneighborsclassifier__n_neighbors=17;, score=0.895 total time=   0.1s
# [CV 4/5] END kneighborsclassifier__n_neighbors=17;, score=0.908 total time=   0.1s
# [CV 5/5] END kneighborsclassifier__n_neighbors=17;, score=0.913 total time=   0.1s
# [CV 1/5] END kneighborsclassifier__n_neighbors=19;, score=0.908 total time=   0.1s
# [CV 2/5] END kneighborsclassifier__n_neighbors=19;, score=0.915 total time=   0.1s
# [CV 3/5] END kneighborsclassifier__n_neighbors=19;, score=0.894 total time=   0.1s
# [CV 4/5] END kneighborsclassifier__n_neighbors=19;, score=0.906 total time=   0.1s
# [CV 5/5] END kneighborsclassifier__n_neighbors=19;, score=0.911 total time=   0.1s
# Best Accuracy: 0.923093220338983
# Best num of neighbors: Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='euclidean', n_neighbors=3))])

# %%
best_k = knn_grid_search.best_params_['kneighborsclassifier__n_neighbors']
best_k
# Out:
# 3

# %%
KNN_final = KNeighborsClassifier(n_neighbors=best_k ,metric='euclidean')
KNN_final.fit(num_train_std, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=3)

# %%
pickle.dump(KNN_final, open("/Users/yihongan/Desktop/KNN.pkl", 'wb'))

# %% [markdown]
# ### SVM Classification Model

# %%
svm_pipe = make_pipeline(StandardScaler(), SVC(probability=True, kernel='rbf'))

svm_parameters = [{
    'svc__C': [0.1, 1, 10, 100],
    'svc__gamma': [0.1, 1, 10, 100],
}]

svm_grid_search = GridSearchCV(svm_pipe, svm_parameters, scoring='accuracy', cv=5, verbose=3 , n_jobs=4, refit=True)
svm_grid_search.fit(num_train, y_train)

print("Best Accuracy: {}" .format(svm_grid_search.best_score_))
print("Best num of neighbors: {}" .format(svm_grid_search.best_estimator_))
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 3/5] END ........svc__C=0.1, svc__gamma=0.1;, score=0.891 total time=  10.0s
# [CV 4/5] END ........svc__C=0.1, svc__gamma=0.1;, score=0.905 total time=  10.2s
# [CV 2/5] END ........svc__C=0.1, svc__gamma=0.1;, score=0.901 total time=  10.3s
# [CV 1/5] END ........svc__C=0.1, svc__gamma=0.1;, score=0.904 total time=  10.4s
# [CV 5/5] END ........svc__C=0.1, svc__gamma=0.1;, score=0.902 total time=  10.8s
# [CV 2/5] END ..........svc__C=0.1, svc__gamma=1;, score=0.746 total time=  20.0s
# [CV 1/5] END ..........svc__C=0.1, svc__gamma=1;, score=0.732 total time=  20.1s
# [CV 3/5] END ..........svc__C=0.1, svc__gamma=1;, score=0.728 total time=  20.0s
# [CV 4/5] END ..........svc__C=0.1, svc__gamma=1;, score=0.730 total time=  20.2s
# [CV 5/5] END ..........svc__C=0.1, svc__gamma=1;, score=0.745 total time=  20.3s
# [CV 1/5] END .........svc__C=0.1, svc__gamma=10;, score=0.646 total time=  34.8s
# [CV 2/5] END .........svc__C=0.1, svc__gamma=10;, score=0.650 total time=  35.3s
# [CV 3/5] END .........svc__C=0.1, svc__gamma=10;, score=0.639 total time=  36.2s
# [CV 4/5] END .........svc__C=0.1, svc__gamma=10;, score=0.641 total time=  35.2s
# [CV 5/5] END .........svc__C=0.1, svc__gamma=10;, score=0.648 total time=  35.1s
# [CV 1/5] END ........svc__C=0.1, svc__gamma=100;, score=0.613 total time=  34.8s
# [CV 2/5] END ........svc__C=0.1, svc__gamma=100;, score=0.615 total time=  32.8s
# [CV 1/5] END ..........svc__C=1, svc__gamma=0.1;, score=0.921 total time=   7.8s
# [CV 3/5] END ........svc__C=0.1, svc__gamma=100;, score=0.612 total time=  33.7s
# [CV 2/5] END ..........svc__C=1, svc__gamma=0.1;, score=0.925 total time=   7.5s
# [CV 3/5] END ..........svc__C=1, svc__gamma=0.1;, score=0.921 total time=   7.4s
# [CV 4/5] END ..........svc__C=1, svc__gamma=0.1;, score=0.923 total time=   7.6s
# [CV 5/5] END ........svc__C=0.1, svc__gamma=100;, score=0.617 total time=  34.0s
# [CV 5/5] END ..........svc__C=1, svc__gamma=0.1;, score=0.928 total time=   7.7s
# [CV 4/5] END ........svc__C=0.1, svc__gamma=100;, score=0.611 total time=  34.6s
# [CV 1/5] END ............svc__C=1, svc__gamma=1;, score=0.861 total time=  21.2s
# [CV 3/5] END ............svc__C=1, svc__gamma=1;, score=0.862 total time=  19.8s
# [CV 2/5] END ............svc__C=1, svc__gamma=1;, score=0.867 total time=  20.2s
# [CV 4/5] END ............svc__C=1, svc__gamma=1;, score=0.863 total time=  20.8s
# [CV 5/5] END ............svc__C=1, svc__gamma=1;, score=0.879 total time=  19.4s
# [CV 2/5] END ...........svc__C=1, svc__gamma=10;, score=0.772 total time=  38.0s
# [CV 1/5] END ...........svc__C=1, svc__gamma=10;, score=0.760 total time=  38.9s
# [CV 3/5] END ...........svc__C=1, svc__gamma=10;, score=0.764 total time=  38.7s
# [CV 4/5] END ...........svc__C=1, svc__gamma=10;, score=0.763 total time=  38.5s
# [CV 1/5] END ..........svc__C=1, svc__gamma=100;, score=0.713 total time=  37.9s
# [CV 5/5] END ...........svc__C=1, svc__gamma=10;, score=0.778 total time=  38.6s
# [CV 2/5] END ..........svc__C=1, svc__gamma=100;, score=0.718 total time=  38.6s
# [CV 1/5] END .........svc__C=10, svc__gamma=0.1;, score=0.926 total time=   8.2s
# [CV 2/5] END .........svc__C=10, svc__gamma=0.1;, score=0.933 total time=   7.7s
# [CV 3/5] END ..........svc__C=1, svc__gamma=100;, score=0.709 total time=  39.6s
# [CV 3/5] END .........svc__C=10, svc__gamma=0.1;, score=0.925 total time=   7.5s
# [CV 4/5] END .........svc__C=10, svc__gamma=0.1;, score=0.927 total time=   7.6s
# [CV 5/5] END .........svc__C=10, svc__gamma=0.1;, score=0.932 total time=   7.8s
# [CV 4/5] END ..........svc__C=1, svc__gamma=100;, score=0.707 total time=  39.9s
# [CV 5/5] END ..........svc__C=1, svc__gamma=100;, score=0.723 total time=  39.8s
# [CV 1/5] END ...........svc__C=10, svc__gamma=1;, score=0.868 total time=  27.3s
# [CV 2/5] END ...........svc__C=10, svc__gamma=1;, score=0.867 total time=  27.1s
# [CV 4/5] END ...........svc__C=10, svc__gamma=1;, score=0.864 total time=  26.9s
# [CV 3/5] END ...........svc__C=10, svc__gamma=1;, score=0.865 total time=  27.0s
# [CV 5/5] END ...........svc__C=10, svc__gamma=1;, score=0.880 total time=  27.2s
# [CV 1/5] END ..........svc__C=10, svc__gamma=10;, score=0.767 total time=  55.6s
# [CV 2/5] END ..........svc__C=10, svc__gamma=10;, score=0.777 total time=  54.3s
# [CV 3/5] END ..........svc__C=10, svc__gamma=10;, score=0.772 total time=  55.3s
# [CV 4/5] END ..........svc__C=10, svc__gamma=10;, score=0.771 total time=  56.2s
# [CV 5/5] END ..........svc__C=10, svc__gamma=10;, score=0.787 total time=  51.6s
# [CV 1/5] END .........svc__C=10, svc__gamma=100;, score=0.719 total time=  54.3s
# [CV 2/5] END .........svc__C=10, svc__gamma=100;, score=0.724 total time=  55.3s
# [CV 1/5] END ........svc__C=100, svc__gamma=0.1;, score=0.927 total time=   8.8s
# [CV 3/5] END .........svc__C=10, svc__gamma=100;, score=0.716 total time=  52.5s
# [CV 2/5] END ........svc__C=100, svc__gamma=0.1;, score=0.920 total time=   8.5s
# [CV 3/5] END ........svc__C=100, svc__gamma=0.1;, score=0.923 total time=   8.9s
# [CV 4/5] END ........svc__C=100, svc__gamma=0.1;, score=0.918 total time=  10.0s
# [CV 5/5] END ........svc__C=100, svc__gamma=0.1;, score=0.928 total time=  11.0s
# [CV 4/5] END .........svc__C=10, svc__gamma=100;, score=0.716 total time=  54.4s
# [CV 5/5] END .........svc__C=10, svc__gamma=100;, score=0.731 total time=  51.6s
# [CV 1/5] END ..........svc__C=100, svc__gamma=1;, score=0.866 total time=  29.3s
# [CV 2/5] END ..........svc__C=100, svc__gamma=1;, score=0.866 total time=  27.6s
# [CV 3/5] END ..........svc__C=100, svc__gamma=1;, score=0.864 total time=  26.5s
# [CV 4/5] END ..........svc__C=100, svc__gamma=1;, score=0.862 total time=  27.8s
# [CV 5/5] END ..........svc__C=100, svc__gamma=1;, score=0.876 total time=  27.7s
# [CV 1/5] END .........svc__C=100, svc__gamma=10;, score=0.766 total time=  57.9s
# [CV 2/5] END .........svc__C=100, svc__gamma=10;, score=0.776 total time=  57.0s
# [CV 3/5] END .........svc__C=100, svc__gamma=10;, score=0.772 total time=  59.2s
# [CV 4/5] END .........svc__C=100, svc__gamma=10;, score=0.772 total time=  57.9s
# [CV 5/5] END .........svc__C=100, svc__gamma=10;, score=0.786 total time=  50.6s
# [CV 1/5] END ........svc__C=100, svc__gamma=100;, score=0.719 total time=  54.3s
# [CV 2/5] END ........svc__C=100, svc__gamma=100;, score=0.724 total time=  53.6s
# [CV 3/5] END ........svc__C=100, svc__gamma=100;, score=0.716 total time=  53.9s
# [CV 4/5] END ........svc__C=100, svc__gamma=100;, score=0.716 total time=  54.5s
# [CV 5/5] END ........svc__C=100, svc__gamma=100;, score=0.732 total time=  52.0s
# Best Accuracy: 0.9285310734463277
# Best num of neighbors: Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(C=10, gamma=0.1, probability=True))])

# %%
svm_grid_search.best_params_
# Out:
# {'svc__C': 10, 'svc__gamma': 0.1}

# %%
svm_final = SVC(probability=True, kernel='rbf', C=10, gamma=0.1)
svm_final.fit(num_train_std, y_train)
# Out:
# SVC(C=10, gamma=0.1, probability=True)

# %%
pickle.dump(svm_final, open("/Users/yihongan/Desktop/SVM.pkl", 'wb'))

# %% [markdown]
# ###  Random Forest Classification Model

# %%
rf =  RandomForestClassifier(random_state=4012)
rf.fit(num_train_std, y_train)
# Out:
# RandomForestClassifier(random_state=4012)

# %%
pickle.dump(rf, open("/Users/yihongan/Desktop/RF.pkl", 'wb'))
